# %% [markdown]
# # Python Basics: Conditionals, Arithmetic, and Loops

# %% [markdown]
# ## 1. If-Else-Elif Statements

# %%
age = 18

if age >= 18:
    print("You are an adult")
else:
    print("You are a minor")
# Out:
# You are an adult

# %%
score = 85

if score >= 90:
    print("Grade: A")
elif score >= 80:
    print("Grade: B")
elif score >= 70:
    print("Grade: C")
elif score >= 60:
    print("Grade: D")
else:
    print("Grade: F")
# Out:
# Grade: B

# %% [markdown]
# ## 2. Arithmetic Operations

# %%
a = 10
b = 5
sum_result = a + b
print(f"Sum: {a} + {b} = {sum_result}")
# Out:
# Sum: 10 + 5 = 15

# %%
x = 20
y = 8
difference = x - y
print(f"Subtraction: {x} - {y} = {difference}")
# Out:
# Subtraction: 20 - 8 = 12

# %%
num1 = 7
num2 = 6
product = num1 * num2
print(f"Multiplication: {num1} × {num2} = {product}")
# Out:
# Multiplication: 7 × 6 = 42

# %%
p = 15
q = 3

print(f"Numbers: {p} and {q}")
print(f"Addition: {p + q}")
print(f"Subtraction: {p - q}")
print(f"Multiplication: {p * q}")
print(f"Division: {p / q}")
print(f"Power: {p ** 2} (p squared)")
# Out:
# Numbers: 15 and 3
# Addition: 18
# Subtraction: 12
# Multiplication: 45
# Division: 5.0
# Power: 225 (p squared)

# %% [markdown]
# ## 3. Loops

# %% [markdown]
# ### For Loop

# %%
print("Counting from 1 to 5:")
for i in range(1, 6):
    print(i)
# Out:
# Counting from 1 to 5:
# 1
# 2
# 3
# 4
# 5

# %%
fruits = ["apple", "banana", "cherry", "date"]
print("My favorite fruits:")
for fruit in fruits:
    print(f"- {fruit}")
# Out:
# My favorite fruits:
# - apple
# - banana
# - cherry
# - date
